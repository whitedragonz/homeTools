# %%
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
kp = pd.read_json("https://services.swpc.noaa.gov/json/planetary_k_index_1m.json")
kp.columns = ['Date Time', 'Kp Index', 'Estimated Kp', 'kp']
kp.iloc[:,0] = pd.to_datetime(kp.iloc[:,0])
kp.iloc[:,2] = pd.to_numeric(kp.iloc[:,2])
kp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 3
#       1 kp = pd.read_json("https://services.swpc.noaa.gov/json/planetary_k_index_1m.json")
#       2 kp.columns = ['Date Time', 'Kp Index', 'Estimated Kp', 'kp']
# ----> 3 kp.iloc[:,0] = pd.to_datetime(kp_6h.iloc[:,0])
#       5 kp
#
# File ~/PythonWork/pycharmprojects/api_test/venv/lib/python3.9/site-packages/pandas/core/indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/PythonWork/pycharmprojects/api_test/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1835, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1832 # align and set the values
#    1833 if take_split_path:
#    1834     # We have to operate column-wise
# -> 1835     self._setitem_with_indexer_split_path(indexer, value, name)
#    1836 else:
#    1837     self._setitem_single_block(indexer, value, name)
#
# File ~/PythonWork/pycharmprojects/api_test/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1891, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1886     if len(value) == 1 and not is_integer(info_axis):
#    1887         # This is a case like df.iloc[:3, [1]] = [0]
#    1888         #  where we treat as df.iloc[:3, 1] = 0
#    1889         return self._setitem_with_indexer((pi, info_axis[0]), value[0])
# -> 1891     raise ValueError(
#    1892         "Must have equal len keys and value "
#    1893         "when setting with an iterable"
#    1894     )
#    1896 elif lplane_indexer == 0 and len(value) == len(self.obj.index):
#    1897     # We get here in one case via .loc with a all-False mask
#    1898     pass
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
kp.iloc[kp.shape[0]-1,2] #kp.shape[0],"estimated_kp"]
# Out:
# 0.33

# %%
kp.at[kp.shape[0]-1,"estimated_kp"] #kp.shape[0],"estimated_kp"]
# Out:
# 0.33

# %%
image = Image.open('https://iswa.gsfc.nasa.gov/IswaSystemWebApp/iSWACygnetStreamer?timestamp=2038-01-23+00%3A44%3A00&window=-1&cygnetId=261')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 image = Image.open('https://iswa.gsfc.nasa.gov/IswaSystemWebApp/iSWACygnetStreamer?timestamp=2038-01-23+00%3A44%3A00&window=-1&cygnetId=261')
#
# File ~/PythonWork/pycharmprojects/api_test/venv/lib/python3.9/site-packages/PIL/Image.py:3236, in open(fp, mode, formats)
#    3233     filename = fp
#    3235 if filename:
# -> 3236     fp = builtins.open(filename, "rb")
#    3237     exclusive_fp = True
#    3239 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://iswa.gsfc.nasa.gov/IswaSystemWebApp/iSWACygnetStreamer?timestamp=2038-01-23+00%3A44%3A00&window=-1&cygnetId=261'

# %%
image = Image.open('iSWACygnetStreamer.gif')

# %%
urllib.request.urlretrieve('https://iswa.gsfc.nasa.gov/IswaSystemWebApp/iSWACygnetStreamer?timestamp=2038-01-23+00%3A44%3A00&window=-1&cygnetId=261','solaractivity.gif')
# Out:
# ('solaractivity.gif', <http.client.HTTPMessage at 0x121f251c0>)

# %%
image = Image.open('solaractivity.gif')

# %%
kp_6h = pd.read_json('https://services.swpc.noaa.gov/products/noaa-planetary-k-index.json')
kp_6h.columns = ['time_tag', 'Kp', 'a_running', 'station_count']
kp_6h.drop(index=[0],inplace=True) #,1))
kp_6h.iloc[:,0] = pd.to_datetime(kp_6h.iloc[:,0])
kp_6h.iloc[:,1] = pd.to_numeric(kp_6h.iloc[:,1])
kp_6h.head()
# Out:
#               time_tag    Kp a_running station_count
# 1  2023-06-14 00:00:00  2.67        12             8
# 2  2023-06-14 03:00:00  1.33         5             8
# 3  2023-06-14 06:00:00  1.33         5             8
# 4  2023-06-14 09:00:00   1.0         4             8
# 5  2023-06-14 12:00:00   1.0         4             8

# %%
kp_6h.plot(x="time_tag",y="Kp",kind='bar',figsize=(120,70),title="NOAA Official Kp",ylabel="Kp",xlabel="Date");

# %%
kp_6h.iloc[:,1] = pd.to_numeric(kp_6h.iloc[:,1])
